# %% [markdown]
# <a href="https://colab.research.google.com/github/rwcitek/NM-Legislature/blob/main/notebooks/bernco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NM Legislature - Capital Outlay Project Requests - Bernalillo County

# %% [markdown]
# From https://www.nmlegis.gov/Legislation/BillFinder/County

# %%
import pandas as pd

# %% [markdown]
# ## MHTML

# %%
url = "https://github.com/rwcitek/NM-Legislature/raw/refs/heads/main/data/bernco.mhtml"
url
# Out:
# 'https://github.com/rwcitek/NM-Legislature/raw/refs/heads/main/data/bernco.mhtml'

# %%
table_list = pd.read_html( url )
len(table_list)
# Out:
# 1

# %%
df = table_list[0]
df.shape
# Out:
# (577, 7)

# %%
df
# Out:
#     Web ID                                Project Title  \
# 0    3787=               ZG ALB SW YOUNG AVE. CONSTRUCT
# 1    3393=     ADA SIDEWALK IMPROVE CITY WIDE IMP= ROVE
# 2    4219=  100TH YEAR ROUTE 66 CELEBRATION CO= NSTRUCT
# 3    3972=     11 RESIDENTIAL STREETS IN D6 CONST= RUCT
# 4    3468=              12TH STREET AND SAWMILL IMPROVE
# ..     ...                                          ...
# 572  3887=     VISTA DEL NORTE DRIVE NE TRIAL IMP= ROVE
# 573  3931=              WEST MESA TRAILS PLAN CONSTRUCT
# 574  3783=         ZG ALB 118TH ST CONSTRUCT CONSTRUCT=
# 575  3761=     ZG ALB BLAKE RD PED SFTY IMPROV DES= IGN
# 576  3756=   ZG ALB SW MESA RD IMPROV ANALYSIS D= ESIGN
#
#                                    Project Description Requested 2025  \
# 0    Plan, design, acquire right-of-way, co= nstruc...     $2,000,000
# 1    to acquire land and rights-of-w= ay, and to pl...     $2,000,000
# 2    Plan, design, construct, pur= chase and instal...     $5,000,000
# ...

# %% [markdown]
# ## HTML

# %%
url2 = "https://github.com/rwcitek/NM-Legislature/raw/refs/heads/main/data/bernco.html"
url2
# Out:
# 'https://github.com/rwcitek/NM-Legislature/raw/refs/heads/main/data/bernco.html'

# %%
table_list = pd.read_html( url2 )
len(table_list)
# Out:
# 1

# %%
df2 = table_list[0]
df2.shape
# Out:
# (577, 7)

# %%
df2
# Out:
#     Web ID                                Project Title  \
# 0    3787=               ZG ALB SW YOUNG AVE. CONSTRUCT
# 1    3393=     ADA SIDEWALK IMPROVE CITY WIDE IMP= ROVE
# 2    4219=  100TH YEAR ROUTE 66 CELEBRATION CO= NSTRUCT
# 3    3972=     11 RESIDENTIAL STREETS IN D6 CONST= RUCT
# 4    3468=              12TH STREET AND SAWMILL IMPROVE
# ..     ...                                          ...
# 572  3887=     VISTA DEL NORTE DRIVE NE TRIAL IMP= ROVE
# 573  3931=              WEST MESA TRAILS PLAN CONSTRUCT
# 574  3783=         ZG ALB 118TH ST CONSTRUCT CONSTRUCT=
# 575  3761=     ZG ALB BLAKE RD PED SFTY IMPROV DES= IGN
# 576  3756=   ZG ALB SW MESA RD IMPROV ANALYSIS D= ESIGN
#
#                                    Project Description Requested 2025  \
# 0    Plan, design, acquire right-of-way, co= nstruc...     $2,000,000
# 1    to acquire land and rights-of-w= ay, and to pl...     $2,000,000
# 2    Plan, design, construct, pur= chase and instal...     $5,000,000
# ...
